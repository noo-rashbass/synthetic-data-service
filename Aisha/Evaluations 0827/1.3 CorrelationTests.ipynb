# %% [markdown]
# ## 1.3 Pearson's Correlation Coefficient Comparison
# This is to test whether the synthetic data has captured dependencies between variables of the original data.
# We calculate Pearson’s correlation coefficients - **_r_**, between categorical columns within the original and synthetic data.
#
# To compare the how similar those _r_'s are,
# * We calculate the **MSE** between every pair of _r_'s (for the same pair of columns but one from synthetic one from real data)
# * We calculate the **SRA** (Synthetic Ranking Agreement,see explanation below) of _r_'s for each column.

# %%
def r_corr_test(df,PTable = False, CoefficientandPtable = False, lower = True ):
    '''Returns a table of Pearson's r correlation coefficients between every pair of columns in the dataframe
    
    Args:
    df: The input dataframe
    PTable: False (default) or True, if True, then the return is a table containing the p(probavility)-value of correlation test.
    CoefficientandPtable: False(default) or True, if true, then the return is a table containing tuples (p-value, r coefficient) from the correlation test.
    lower: True(default) or False. If True, the lower triangle part of the table is filled with the transpose of the upper triangle part rather than leaved with None.
    
    Returns:
    The requested table as specified in the args. If PTable and CoefficientandPtable are all False, then the return table consists of coefficient values only.
    
    '''
    from scipy.stats import pearsonr
    import pandas as pd
    import numpy as np

    df_index = (df.keys()).tolist()
    n = len(df_index)
    ini = [ [ None for y in range( n ) ] 
                 for x in range( n ) ]

    #pearsonr returns two values: the correlation coefficient and significance test probability p
    #so we create two empty dataframes to store them
    coefficient_table = pd.DataFrame(ini,index = df_index,columns = df_index)
    p_table = coefficient_table.copy()
    coe_and_p_table = coefficient_table.copy()

    for i in range(n):
        for j in range(i+1,n):
            name1 = df_index[i]
            name2 = df_index[j]
            obs_1 = df[name1].dropna()
            obs_2 = df[name2].dropna()
            dataframe = pd.DataFrame({name1: obs_1, name2: obs_2})

            values = dataframe.dropna().values
            (coe,p) = pearsonr(values[:,0],values[:,1])
            coefficient_table.loc[name1,name2]=coe
            p_table.loc[name1,name2]=p
            coe_and_p_table.loc[name1,name2]=(coe,p)
    
    if lower:
        #A function that can fill the lower part of the dataframe, because coe_table and p_table has their lower triangles empty
        #But for comparison reasons you may want them to be filled
        def fill_lower(df):
            n = df.values.shape[0]
            for j in range(n):
                for i in range(j+1,n):
                    df.iloc[i,j]=df.iloc[j,i]
            return df
        
        coefficient_table = fill_lower(coefficient_table)
        p_table = fill_lower(p_table)
        coe_and_p_table = fill_lower(coe_and_p_table)
    
    
    if PTable:
        return p_table
    elif CoefficientandPtable:
        return coe_and_p_table
    else:
        return coefficient_table

# %% [markdown]
# ## What is SRA?
# **SRA** is used when we want to test whether a synthetic dataset respects a certain ranking. Suppose we have a list of metrics $ R_{1}, R_{2}, R_{3} ... R_{n} $ calculated from the real data and a list of same metrics $ S_{1}, S_{2}, S_{3} ... S_{n} $ calculated from the synthetic data. Then we define **SRA** as
# $$
# SRA(R,S) = \frac{1}{n(n-1)} \sum_{i=1}^{n}\sum_{j\neq{i}} Id((S_{i}-S_{j})\times(R_{i}-R_{j})>0)\\
# $$
# where $ Id $ is the identity function. $ SRA \in [0,1] $, The closer the SRA to $ 1 $, the better the ranking agreement.
#
# In the case of correlation comparison, suppose we have columns _A, B, C, D, E_ , for column _A_, we calculate correlation coefficients $ r_{AB}, r_{AC}, r_{AD}, r_{AE} $ for the real data, and $ r'_{AB}, r'_{AC}, r'_{AD}, r'_{AE} $ for the synthetic data. We hope the ranking of $ r $ and $ r' $ agrees, e.g. if $ r_{AB} > r_{AC} $ then $ r'_{AB} > r'_{AC} $ as well. As a result, our $ R $ is $ r_{AB}, r_{AC}, r_{AD}, r_{AE} $, $ S $ is $ r'_{AB}, r'_{AC}, r'_{AD}, r'_{AE} $, and we can calulate the $ SRA $ for each column.

# %%
def SRA(R,S):
    '''Calculate the SRA of lists R and S
    
    Args:
    - R: A list of performance metrics of different predictive models from TSTS
    - S: A list of performance metrics of different predictive models from TRTR, len(S)=len(R)
    
    Returns:
    - SRA: SRA value
    
    '''
    def identity_function(statement):
        v = 0
        if statement:
            v = 1
        return v
            
    k = len(R)
    sum_ = 0
    for i in range(k):
        for j in range(k):
            if i != j:
                if (R[i]-R[j])==0:
                    if (S[i]-S[j])==0:
                        agree = True
                    else:
                        agree = False
                else:
                    agree = (R[i]-R[j])*(S[i]-S[j])>0
                sum_ += identity_function(agree)
    SRA = sum_ / (k*(k-1))
    return SRA

# %%
def CorrelationSRA(ori_correlation_df,gen_correlation_df,ColumnWise = False):
    '''Returns the value of SRA for the absolute Pearsons correlation coefficients for each column between \
    all other columns. SRA is between 0 and 1, the closer the SRA is to 1, the more the agreement between the ranking,\
    the more similar the synthetic data and the real data are.
    
    Args:
    ori_correlation_df: the correlation coefficient dataframe for the real data, usually generated from the function\
                        r_corr_test.
    gen_correlation_df: the correlation coefficient dataframe for the synthetic data, usually generated from the function\
                        r_corr_test. 
    ColumnWise: False(default) or True. If True, the return is a Series containing the SRA value for each column and the average.\
                Otherwise, the return is the average of SRA values for all columns
    
    Returns:
    s: It is either a column-wise SRA series or the average SRA values of them, determined by the arg ColumnWise.
    
    '''
    import numpy as np
    import pandas as pd
    
    columns = (ori_correlation_df.keys()).tolist()
    n = len(columns)
    ini = np.ones(n)
    
    for i in range(n):
        ori_values = ori_correlation_df.iloc[i,:].dropna()
        gen_values = gen_correlation_df.iloc[i,:].dropna()
        ini[i] = SRA(abs(ori_values), abs(gen_values))
    
    if ColumnWise:
        s = pd.Series(ini,index = columns)
        s['average'] = sum(ini)/n
    else:
        s = sum(ini)/n
    return s

# %%
def MSE(r_table_ori,r_table_gen):
    '''
    Returns the MSE for each position between two dataframes and an average value.
    '''
    import pandas as pd
    import numpy as np
    ori = r_table_ori.fillna(0).values
    gen = r_table_gen.fillna(0).values
    columns = (r_table_gen.keys()).tolist()
    matrix = (ori-gen)**2
    df = pd.DataFrame(matrix, index = columns, columns = columns)
    score = np.sum(matrix)/(len(ori)*(len(ori)-1)) #The diagonal is always zero so we don't count them
    return df, score

# %% [markdown]
# # Data Loading

# %%
import numpy as np
import pandas as pd
dp_ori_df = pd.read_csv('synthetic data/doppelGANger/dp_ori.csv') #originally ori_features_prism.npy
dp_gen_df = pd.read_csv('synthetic data/doppelGANger/dp_gen.csv') #originally features_600.npy
tgan_ori_df = pd.read_csv('synthetic data/TGAN/tgan_ori.csv') #originally cat_time_10visits_all_noid.csv
tgan_gen_df = pd.read_csv('synthetic data/TGAN/tgan_gen.csv') #originally gen_cat_time_10visits_wl_5000it.npy
ori_df = pd.read_csv('synthetic data/2_no_id/ori_df.csv') #originally cat_time_5abovevisits_all.csv
gen_1_df = pd.read_csv('synthetic data/2_no_id/gen_1_df.csv') #originally gen_cat_time_10visits_wl_5000it_hd10_nl5.npy
gen_2_df = pd.read_csv('synthetic data/2_no_id/gen_2_df.csv') #originally gen_cat_time_10visits_wl_5000it_hd10.npy
gen_3_df = pd.read_csv('synthetic data/2_no_id/gen_3_df.csv') #originally gen_dop_cat_5abovevisits_d2g_e449.npy
gen_4_df = pd.read_csv('synthetic data/2_no_id/gen_4_df.csv') #originally from gen_cat_time_10visits_all_5000it.npy.
dp_0827_df = pd.read_csv('synthetic data/2_no_id/dp_0827_gen.csv')  #originally gen_doptf2_cat_5abovevisits_e200_lstm.csv

synthetic_data_dic = {'DoppelGANger_0814':[dp_ori_df, dp_gen_df],'DoppelGANger_0824':[ori_df,gen_3_df],\
                      'DoppelGANger_0827':[ori_df,dp_0827_df],'tGAN':[tgan_ori_df,tgan_gen_df],\
                      'tGAN 1':[tgan_ori_df,gen_1_df],'tGAN 2':[tgan_ori_df,gen_2_df],\
                     'tGAN 4':[tgan_ori_df,gen_4_df]}
syn_keys = list(synthetic_data_dic.keys())

# %%
n = len(syn_keys)
MSE_array = np.zeros(n)
for i in range(n):
    key = syn_keys[i]
    df_ori = synthetic_data_dic[key][0]
    df_gen = synthetic_data_dic[key][1]
    r_table_ori = r_corr_test(df_ori)
    r_table_gen = r_corr_test(df_gen)
    
    #Highlight all r values > 0.5 as yellow, indicating strong correlation
    def color_threshold_yellow(val):
        threshold = 0.5
        if ((val != None) and (abs(val) > threshold)):
            color = 'yellow' 
        else:
            color = 'black'
        return 'color: %s' % color

    display(key+' '+'generated r table',r_table_gen.style.applymap(color_threshold_yellow))
    display(key+' '+'real r table',r_table_ori.style.applymap(color_threshold_yellow))
    sra = CorrelationSRA(r_table_ori,r_table_gen,ColumnWise=True)
    if i==0:
        sra_df = pd.DataFrame(sra,columns = [key])
    else:
        sra_df = pd.concat([sra_df,pd.DataFrame(sra,columns = [key])], axis = 1, sort = False)
    display(key+' '+'SRA',sra)
    MSE_df, MSE_score = MSE(r_table_gen,r_table_ori)
    display(key+' '+'MSE table', MSE_df)
    MSE_array[i] = MSE_score
MSE_series = pd.Series(MSE_array,index = syn_keys)
# Out:
# 'DoppelGANger_0814 generated r table'
# <style  type="text/css" >
#     #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row0_col0 {
#             color:  black;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row0_col1 {
#             color:  black;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row0_col2 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row0_col3 {
#             color:  black;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row0_col4 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row1_col0 {
#             color:  black;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row1_col1 {
#             color:  black;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row1_col2 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row1_col3 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row1_col4 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row2_col0 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row2_col1 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row2_col2 {
#             color:  black;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row2_col3 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row2_col4 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row3_col0 {
#             color:  black;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row3_col1 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row3_col2 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row3_col3 {
#             color:  black;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row3_col4 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row4_col0 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row4_col1 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row4_col2 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row4_col3 {
#             color:  yellow;
#         }    #T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row4_col4 {
#             color:  black;
#         }</style><table id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dday</th>        <th class="col_heading level0 col1" >weight</th>        <th class="col_heading level0 col2" >height</th>        <th class="col_heading level0 col3" >age</th>        <th class="col_heading level0 col4" >temp</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4level0_row0" class="row_heading level0 row0" >dday</th>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row0_col0" class="data row0 col0" >None</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row0_col1" class="data row0 col1" >0.460590</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row0_col2" class="data row0 col2" >0.579901</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row0_col3" class="data row0 col3" >0.385757</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row0_col4" class="data row0 col4" >0.572924</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4level0_row1" class="row_heading level0 row1" >weight</th>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row1_col0" class="data row1 col0" >0.460590</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row1_col1" class="data row1 col1" >None</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row1_col2" class="data row1 col2" >0.852360</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row1_col3" class="data row1 col3" >0.765801</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row1_col4" class="data row1 col4" >0.725225</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4level0_row2" class="row_heading level0 row2" >height</th>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row2_col0" class="data row2 col0" >0.579901</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row2_col1" class="data row2 col1" >0.852360</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row2_col2" class="data row2 col2" >None</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row2_col3" class="data row2 col3" >0.700063</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row2_col4" class="data row2 col4" >0.951644</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4level0_row3" class="row_heading level0 row3" >age</th>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row3_col0" class="data row3 col0" >0.385757</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row3_col1" class="data row3 col1" >0.765801</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row3_col2" class="data row3 col2" >0.700063</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row3_col3" class="data row3 col3" >None</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row3_col4" class="data row3 col4" >0.561933</td>
#             </tr>
#             <tr>
#                         <th id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4level0_row4" class="row_heading level0 row4" >temp</th>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row4_col0" class="data row4 col0" >0.572924</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row4_col1" class="data row4 col1" >0.725225</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row4_col2" class="data row4 col2" >0.951644</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row4_col3" class="data row4 col3" >0.561933</td>
#                         <td id="T_3ec7b284_e87a_11ea_ba2c_d4619d24eda4row4_col4" class="data row4 col4" >None</td>
#             </tr>
#     </tbody></table>
# 'DoppelGANger_0814 real r table'
# <style  type="text/css" >
#     #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row0_col0 {
#             color:  black;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row0_col1 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row0_col2 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row0_col3 {
#             color:  black;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row0_col4 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row1_col0 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row1_col1 {
#             color:  black;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row1_col2 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row1_col3 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row1_col4 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row2_col0 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row2_col1 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row2_col2 {
#             color:  black;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row2_col3 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row2_col4 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row3_col0 {
#             color:  black;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row3_col1 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row3_col2 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row3_col3 {
#             color:  black;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row3_col4 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row4_col0 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row4_col1 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row4_col2 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row4_col3 {
#             color:  yellow;
#         }    #T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row4_col4 {
#             color:  black;
#         }</style><table id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dday</th>        <th class="col_heading level0 col1" >weight</th>        <th class="col_heading level0 col2" >height</th>        <th class="col_heading level0 col3" >age</th>        <th class="col_heading level0 col4" >temp</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4level0_row0" class="row_heading level0 row0" >dday</th>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row0_col0" class="data row0 col0" >None</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row0_col1" class="data row0 col1" >0.547442</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row0_col2" class="data row0 col2" >0.625742</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row0_col3" class="data row0 col3" >0.431480</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row0_col4" class="data row0 col4" >0.624604</td>
#             </tr>
#             <tr>
#                         <th id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4level0_row1" class="row_heading level0 row1" >weight</th>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row1_col0" class="data row1 col0" >0.547442</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row1_col1" class="data row1 col1" >None</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row1_col2" class="data row1 col2" >0.904009</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row1_col3" class="data row1 col3" >0.888397</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row1_col4" class="data row1 col4" >0.787127</td>
#             </tr>
#             <tr>
#                         <th id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4level0_row2" class="row_heading level0 row2" >height</th>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row2_col0" class="data row2 col0" >0.625742</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row2_col1" class="data row2 col1" >0.904009</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row2_col2" class="data row2 col2" >None</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row2_col3" class="data row2 col3" >0.739106</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row2_col4" class="data row2 col4" >0.964485</td>
#             </tr>
#             <tr>
#                         <th id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4level0_row3" class="row_heading level0 row3" >age</th>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row3_col0" class="data row3 col0" >0.431480</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row3_col1" class="data row3 col1" >0.888397</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row3_col2" class="data row3 col2" >0.739106</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row3_col3" class="data row3 col3" >None</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row3_col4" class="data row3 col4" >0.589636</td>
#             </tr>
#             <tr>
#                         <th id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4level0_row4" class="row_heading level0 row4" >temp</th>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row4_col0" class="data row4 col0" >0.624604</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row4_col1" class="data row4 col1" >0.787127</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row4_col2" class="data row4 col2" >0.964485</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row4_col3" class="data row4 col3" >0.589636</td>
#                         <td id="T_3ecabee8_e87a_11ea_ba2c_d4619d24eda4row4_col4" class="data row4 col4" >None</td>
#             </tr>
#     </tbody></table>
# 'DoppelGANger_0814 SRA'
# dday       1.0
# weight     1.0
# height     1.0
# age        1.0
# temp       1.0
# average    1.0
# dtype: float64
# 'DoppelGANger_0814 MSE table'
#             dday    weight    height       age      temp
# dday    0.000000  0.007543  0.002101  0.002091  0.002671
# weight  0.007543  0.000000  0.002668  0.015030  0.003832
# height  0.002101  0.002668  0.000000  0.001524  0.000165
# age     0.002091  0.015030  0.001524  0.000000  0.000767
# temp    0.002671  0.003832  0.000165  0.000767  0.000000
# 'DoppelGANger_0824 generated r table'
# <style  type="text/css" >
#     #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row0_col0 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row0_col1 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row0_col2 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row0_col3 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row0_col4 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row0_col5 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row0_col6 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row0_col7 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row0_col8 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row0_col9 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row1_col0 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row1_col1 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row1_col2 {
#             color:  yellow;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row1_col3 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row1_col4 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row1_col5 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row1_col6 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row1_col7 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row1_col8 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row1_col9 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row2_col0 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row2_col1 {
#             color:  yellow;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row2_col2 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row2_col3 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row2_col4 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row2_col5 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row2_col6 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row2_col7 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row2_col8 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row2_col9 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row3_col0 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row3_col1 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row3_col2 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row3_col3 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row3_col4 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row3_col5 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row3_col6 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row3_col7 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row3_col8 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row3_col9 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row4_col0 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row4_col1 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row4_col2 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row4_col3 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row4_col4 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row4_col5 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row4_col6 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row4_col7 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row4_col8 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row4_col9 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row5_col0 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row5_col1 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row5_col2 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row5_col3 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row5_col4 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row5_col5 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row5_col6 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row5_col7 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row5_col8 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row5_col9 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row6_col0 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row6_col1 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row6_col2 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row6_col3 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row6_col4 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row6_col5 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row6_col6 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row6_col7 {
#             color:  yellow;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row6_col8 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row6_col9 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row7_col0 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row7_col1 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row7_col2 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row7_col3 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row7_col4 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row7_col5 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row7_col6 {
#             color:  yellow;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row7_col7 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row7_col8 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row7_col9 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row8_col0 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row8_col1 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row8_col2 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row8_col3 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row8_col4 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row8_col5 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row8_col6 {
#             color:  black;
#         }    #T_3f76ef92_e87a_11ea_ba2c_d4619d24eda4row8_col7
# 'DoppelGANger_0824 real r table'
# <style  type="text/css" >
#     #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row0_col0 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row0_col1 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row0_col2 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row0_col3 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row0_col4 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row0_col5 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row0_col6 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row0_col7 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row0_col8 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row0_col9 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row1_col0 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row1_col1 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row1_col2 {
#             color:  yellow;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row1_col3 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row1_col4 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row1_col5 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row1_col6 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row1_col7 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row1_col8 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row1_col9 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row2_col0 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row2_col1 {
#             color:  yellow;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row2_col2 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row2_col3 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row2_col4 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row2_col5 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row2_col6 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row2_col7 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row2_col8 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row2_col9 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row3_col0 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row3_col1 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row3_col2 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row3_col3 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row3_col4 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row3_col5 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row3_col6 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row3_col7 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row3_col8 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row3_col9 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row4_col0 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row4_col1 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row4_col2 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row4_col3 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row4_col4 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row4_col5 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row4_col6 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row4_col7 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row4_col8 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row4_col9 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row5_col0 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row5_col1 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row5_col2 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row5_col3 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row5_col4 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row5_col5 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row5_col6 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row5_col7 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row5_col8 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row5_col9 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row6_col0 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row6_col1 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row6_col2 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row6_col3 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row6_col4 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row6_col5 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row6_col6 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row6_col7 {
#             color:  yellow;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row6_col8 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row6_col9 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row7_col0 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row7_col1 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row7_col2 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row7_col3 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row7_col4 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row7_col5 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row7_col6 {
#             color:  yellow;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row7_col7 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row7_col8 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row7_col9 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row8_col0 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row8_col1 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row8_col2 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row8_col3 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row8_col4 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row8_col5 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row8_col6 {
#             color:  black;
#         }    #T_3f8380f4_e87a_11ea_ba2c_d4619d24eda4row8_col7
# 'DoppelGANger_0824 SRA'
# dday         0.361111
# height       0.750000
# weight       0.638889
# temp         0.444444
# vomit_dur    0.555556
# cough_dur    0.833333
# diar_No      0.583333
# diar_Yes     0.611111
# head_No      0.638889
# head_Yes     0.611111
# average      0.602778
# dtype: float64
# 'DoppelGANger_0824 MSE table'
#                dday    height    weight      temp  vomit_dur  cough_dur  \
# dday       0.000000  0.015874  0.053744  0.022426   0.005987   0.000172
# height     0.015874  0.000000  0.012915  0.180783   0.004019   0.000010
# weight     0.053744  0.012915  0.000000  0.162191   0.003762   0.000719
# temp       0.022426  0.180783  0.162191  0.000000   0.010810   0.000413
# vomit_dur  0.005987  0.004019  0.003762  0.010810   0.000000   0.005746
# cough_dur  0.000172  0.000010  0.000719  0.000413   0.005746   0.000000
# diar_No    0.003867  0.043471  0.025112  0.162304   0.014660   0.000813
# diar_Yes   0.003867  0.043471  0.025112  0.162304   0.014660   0.000813
# head_No    0.000571  0.102443  0.077229  0.243921   0.000077   0.010957
# head_Yes   0.000571  0.102443  0.077229  0.243921   0.000077   0.010957
#
#                 diar_No      diar_Yes       head_No      head_Yes
# dday       3.867285e-03  3.867285e-03  5.709811e-04  5.709811e-04
# height     4.347078e-02  4.347078e-02  1.024431e-01  1.024431e-01
# weight     2.511168e-02  2.511168e-02  7.722939e-02  7.722939e-02
# temp       1.623037e-01  1.623037e-01  2.439214e-01  2.439214e-01
# vomit_dur  1.465964e-02  1.465964e-02  7.685961e-05  7.685963e-05
# cough_dur  8.133489e-04  8.133491e-04  1.095699e-02  1.095699e-02
# diar_No    0.000000e+00  3.810395e-27  8.619110e-02  8.619110e-02
# diar_Yes   3.810395e-27  0.000000e+00  8.619110e-02  8.619110e-02
# head_No    8.619110e-02  8.619110e-02  0.000000e+00  5.230641e-28
# head_Yes   8.619110e-02  8.619110e-02  5.230641e-28  0.000000e+00
# 'DoppelGANger_0827 generated r table'
# <style  type="text/css" >
#     #T_402be172_e87a_11ea_ba2c_d4619d24eda4row0_col0 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row0_col1 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row0_col2 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row0_col3 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row0_col4 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row0_col5 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row0_col6 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row0_col7 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row0_col8 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row0_col9 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row1_col0 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row1_col1 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row1_col2 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row1_col3 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row1_col4 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row1_col5 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row1_col6 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row1_col7 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row1_col8 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row1_col9 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row2_col0 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row2_col1 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row2_col2 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row2_col3 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row2_col4 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row2_col5 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row2_col6 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row2_col7 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row2_col8 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row2_col9 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row3_col0 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row3_col1 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row3_col2 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row3_col3 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row3_col4 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row3_col5 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row3_col6 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row3_col7 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row3_col8 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row3_col9 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row4_col0 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row4_col1 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row4_col2 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row4_col3 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row4_col4 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row4_col5 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row4_col6 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row4_col7 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row4_col8 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row4_col9 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row5_col0 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row5_col1 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row5_col2 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row5_col3 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row5_col4 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row5_col5 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row5_col6 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row5_col7 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row5_col8 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row5_col9 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row6_col0 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row6_col1 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row6_col2 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row6_col3 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row6_col4 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row6_col5 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row6_col6 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row6_col7 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row6_col8 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row6_col9 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row7_col0 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row7_col1 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row7_col2 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row7_col3 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row7_col4 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row7_col5 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row7_col6 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row7_col7 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row7_col8 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row7_col9 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row8_col0 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row8_col1 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row8_col2 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row8_col3 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row8_col4 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row8_col5 {
#             color:  black;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4row8_col6 {
#             color:  yellow;
#         }    #T_402be172_e87a_11ea_ba2c_d4619d24eda4r
# 'DoppelGANger_0827 real r table'
# <style  type="text/css" >
#     #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row0_col0 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row0_col1 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row0_col2 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row0_col3 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row0_col4 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row0_col5 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row0_col6 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row0_col7 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row0_col8 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row0_col9 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row1_col0 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row1_col1 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row1_col2 {
#             color:  yellow;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row1_col3 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row1_col4 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row1_col5 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row1_col6 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row1_col7 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row1_col8 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row1_col9 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row2_col0 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row2_col1 {
#             color:  yellow;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row2_col2 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row2_col3 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row2_col4 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row2_col5 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row2_col6 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row2_col7 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row2_col8 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row2_col9 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row3_col0 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row3_col1 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row3_col2 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row3_col3 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row3_col4 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row3_col5 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row3_col6 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row3_col7 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row3_col8 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row3_col9 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row4_col0 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row4_col1 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row4_col2 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row4_col3 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row4_col4 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row4_col5 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row4_col6 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row4_col7 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row4_col8 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row4_col9 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row5_col0 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row5_col1 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row5_col2 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row5_col3 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row5_col4 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row5_col5 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row5_col6 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row5_col7 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row5_col8 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row5_col9 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row6_col0 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row6_col1 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row6_col2 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row6_col3 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row6_col4 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row6_col5 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row6_col6 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row6_col7 {
#             color:  yellow;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row6_col8 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row6_col9 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row7_col0 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row7_col1 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row7_col2 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row7_col3 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row7_col4 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row7_col5 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row7_col6 {
#             color:  yellow;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row7_col7 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row7_col8 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row7_col9 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row8_col0 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row8_col1 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row8_col2 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row8_col3 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row8_col4 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row8_col5 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row8_col6 {
#             color:  black;
#         }    #T_4035db50_e87a_11ea_ba2c_d4619d24eda4row8_col7
# 'DoppelGANger_0827 SRA'
# dday         0.333333
# height       0.555556
# weight       0.444444
# temp         0.527778
# vomit_dur    0.583333
# cough_dur    0.472222
# diar_No      0.527778
# diar_Yes     0.500000
# head_No      0.583333
# head_Yes     0.555556
# average      0.508333
# dtype: float64
# 'DoppelGANger_0827 MSE table'
# ...
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row2_col0 {
#             color:  yellow;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row2_col1 {
#             color:  yellow;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row2_col2 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row2_col3 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row2_col4 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row2_col5 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row2_col6 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row2_col7 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row2_col8 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row2_col9 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row3_col0 {
#             color:  yellow;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row3_col1 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row3_col2 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row3_col3 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row3_col4 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row3_col5 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row3_col6 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row3_col7 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row3_col8 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row3_col9 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row4_col0 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row4_col1 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row4_col2 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row4_col3 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row4_col4 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row4_col5 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row4_col6 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row4_col7 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row4_col8 {
#             color:  yellow;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row4_col9 {
#             color:  yellow;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row5_col0 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row5_col1 {
#             color:  yellow;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row5_col2 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row5_col3 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row5_col4 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row5_col5 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row5_col6 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row5_col7 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row5_col8 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row5_col9 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row6_col0 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row6_col1 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row6_col2 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row6_col3 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row6_col4 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row6_col5 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row6_col6 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row6_col7 {
#             color:  yellow;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row6_col8 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row6_col9 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row7_col0 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row7_col1 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row7_col2 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row7_col3 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row7_col4 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row7_col5 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row7_col6 {
#             color:  yellow;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row7_col7 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row7_col8 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row7_col9 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row8_col0 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row8_col1 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row8_col2 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row8_col3 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row8_col4 {
#             color:  yellow;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row8_col5 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda4row8_col6 {
#             color:  black;
#         }    #T_42511ed6_e87a_11ea_ba2c_d4619d24eda
# 'tGAN 4 real r table'
# <style  type="text/css" >
#     #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row0_col0 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row0_col1 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row0_col2 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row0_col3 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row0_col4 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row0_col5 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row0_col6 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row0_col7 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row0_col8 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row0_col9 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row1_col0 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row1_col1 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row1_col2 {
#             color:  yellow;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row1_col3 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row1_col4 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row1_col5 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row1_col6 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row1_col7 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row1_col8 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row1_col9 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row2_col0 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row2_col1 {
#             color:  yellow;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row2_col2 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row2_col3 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row2_col4 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row2_col5 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row2_col6 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row2_col7 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row2_col8 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row2_col9 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row3_col0 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row3_col1 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row3_col2 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row3_col3 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row3_col4 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row3_col5 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row3_col6 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row3_col7 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row3_col8 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row3_col9 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row4_col0 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row4_col1 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row4_col2 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row4_col3 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row4_col4 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row4_col5 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row4_col6 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row4_col7 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row4_col8 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row4_col9 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row5_col0 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row5_col1 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row5_col2 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row5_col3 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row5_col4 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row5_col5 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row5_col6 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row5_col7 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row5_col8 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row5_col9 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row6_col0 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row6_col1 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row6_col2 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row6_col3 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row6_col4 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row6_col5 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row6_col6 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row6_col7 {
#             color:  yellow;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row6_col8 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row6_col9 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row7_col0 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row7_col1 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row7_col2 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row7_col3 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row7_col4 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row7_col5 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row7_col6 {
#             color:  yellow;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row7_col7 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row7_col8 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row7_col9 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row8_col0 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row8_col1 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row8_col2 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row8_col3 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row8_col4 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row8_col5 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row8_col6 {
#             color:  black;
#         }    #T_425d0a52_e87a_11ea_ba2c_d4619d24eda4row8_col7
# 'tGAN 4 SRA'
# dday         0.611111
# height       0.694444
# weight       0.694444
# temp         0.527778
# vomit_dur    0.555556
# cough_dur    0.444444
# diar_No      0.583333
# diar_Yes     0.583333
# head_No      0.694444
# head_Yes     0.694444
# average      0.608333
# dtype: float64
# 'tGAN 4 MSE table'
#                dday    height    weight      temp  vomit_dur  cough_dur  \
# dday       0.000000  0.301524  0.318359  0.375500   0.129292   0.037557
# height     0.301524  0.000000  0.000885  0.008907   0.003731   0.245051
# weight     0.318359  0.000885  0.000000  0.027936   0.000718   0.075120
# temp       0.375500  0.008907  0.027936  0.000000   0.130447   0.002854
# vomit_dur  0.129292  0.003731  0.000718  0.130447   0.000000   0.176366
# cough_dur  0.037557  0.245051  0.075120  0.002854   0.176366   0.000000
# diar_No    0.107354  0.062906  0.028124  0.099466   0.000022   0.079986
# diar_Yes   0.122683  0.070354  0.033429  0.123930   0.000013   0.081052
# head_No    0.053085  0.000234  0.000565  0.038116   0.696706   0.086054
# head_Yes   0.052770  0.000231  0.000578  0.037830   0.696002   0.086356
#
#             diar_No  diar_Yes       head_No      head_Yes
# dday       0.107354  0.122683  5.308513e-02  5.276953e-02
# height     0.062906  0.070354  2.342499e-04  2.308390e-04
# weight     0.028124  0.033429  5.649137e-04  5.777484e-04
# temp       0.099466  0.123930  3.811595e-02  3.782954e-02
# vomit_dur  0.000022  0.000013  6.967063e-01  6.960018e-01
# cough_dur  0.079986  0.081052  8.605441e-02  8.635610e-02
# diar_No    0.000000  0.000007  6.263326e-03  6.221130e-03
# diar_Yes   0.000007  0.000000  8.020146e-03  7.966082e-03
# head_No    0.006263  0.008020  0.000000e+00  6.311835e-11
# head_Yes   0.006221  0.007966  6.311835e-11  0.000000e+00

# %%
display('MSE values of r for each synthetic data',MSE_series)
# Out:
# 'MSE values of r for each synthetic data'
# DoppelGANger_0814    0.003839
# DoppelGANger_0824    0.048782
# DoppelGANger_0827    0.112824
# tGAN                 0.315190
# tGAN 1               0.129868
# tGAN 2               0.111499
# tGAN 4               0.098235
# dtype: float64

# %% [markdown]
# ## Conclusion
# * The lower the value of MSE, the smaller the average difference between the correlation coefficients between the real and synthetic data, hence the better the result.
#
# * DoppelGANger_0814 is good but it contains only 5 columns.
#
# * tGAN, gen 1 and gen 2 have large MSE values, by comparing the correlation tables we find that these generated datas have wronly too strong dependencies (r>0.5) between some columns.
#
# * DoppelGANger_0824 agrees with its original data in all r>0.5. DoppelGANger_0827 doesn't do well in categorical columns (diar and head), wrongly strong dependencies between these columns.

# %%
display('SRA for each column and synthetic data',sra_df)
# Out:
# 'SRA for each column and synthetic data'
#            DoppelGANger_0814  DoppelGANger_0824  DoppelGANger_0827      tGAN  \
# dday                     1.0           0.361111           0.333333  0.694444
# weight                   1.0           0.638889           0.444444  0.555556
# height                   1.0           0.750000           0.555556  0.638889
# age                      1.0                NaN                NaN       NaN
# temp                     1.0           0.444444           0.527778  0.750000
# average                  1.0           0.602778           0.508333  0.600000
# vomit_dur                NaN           0.555556           0.583333  0.166667
# cough_dur                NaN           0.833333           0.472222  0.583333
# diar_No                  NaN           0.583333           0.527778  0.500000
# diar_Yes                 NaN           0.611111           0.500000  0.500000
# head_No                  NaN           0.638889           0.583333  0.805556
# head_Yes                 NaN           0.611111           0.555556  0.805556
#
#              tGAN 1    tGAN 2    tGAN 4
# dday       0.333333  0.861111  0.611111
# weight     0.527778  0.805556  0.694444
# height     0.527778  0.694444  0.694444
# age             NaN       NaN       NaN
# temp       0.861111  0.361111  0.527778
# average    0.588889  0.666667  0.608333
# vomit_dur  0.611111  0.750000  0.555556
# cough_dur  0.500000  0.500000  0.444444
# diar_No    0.527778  0.833333  0.583333
# diar_Yes   0.555556  0.805556  0.583333
# head_No    0.722222  0.527778  0.694444
# head_Yes   0.722222  0.527778  0.694444

# %% [markdown]
# ## Conclusion
# * we can conclude that DoppleGANger_0814preserves the dependency ranking between columns very well.
#
# * By comparing the 'average', tGAN 2 is best at preserve the ranking. Though in the previous section we find that tGAN 2 tends to have a large r value in average.
# * DoppelGANger_0827 achives the lowest SRA by comparing the average.

# %% [markdown]
# ## Possible Improvements in this method
# Note in the TGAN data, it contains categorical columns e.g. diar_No and diar_Yes between which the _r_ is -1. This corresponding to the logic fact that if diar_No = 1, then diar_Yes = 0; if diar_No = 0, then diar_Yes = 1. A reasonable synthetic data has to respect this kind of 'logic' relationship.
#
# As a result, it's reasonable to say that that larger the absolute value of _r_ is, the more important the relationship is, that's why we choose to use MSE rather than MAE in quantitative evaluation, a possible improvement is adding weight according to _r_ rather than averaging the MSE.

# %% [markdown]
# **Reference:**
# <!--[Text](link)-->
# * [James Jordon, Jinsung Yoon, Mihaela van der Schaar. PATE-GAN: GENERATING SYNTHETIC DATA WITH
# DIFFERENTIAL PRIVACY GUARANTEES](https://openreview.net/pdf?id=S1zk9iRqF7)
