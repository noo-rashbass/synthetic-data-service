# %%
import pandas as pd
data = pd.read_csv('../isaFull.tsv', '\t')

# %%
for i in data.columns:
    print( i )
    print( "Number unique items: ");print(len(data[i].unique()) )
    if len(data[i].unique())<100:
        print( "The unique items: ");print(list(data[i].unique()) )
    else:
        print( [data[i].unique()[0],
               data[i].unique()[-1]] )
#
# Out:
# Observation_Id
# Number unique items:
# 48722
# [100118961, 350120999]
# Participant_Id
# Number unique items:
# 1421
# [1001, 3501]
# Household_Id
# Number unique items:
# 331
# ['HH216001613', 'HH134007801']
# Abdominal pain [HP_0002027]
# Number unique items:
# 4
# The unique items:
# ['No', 'Yes', 'Unable to assess', nan]
# Abdominal pain duration (days) [EUPATH_0000154]
# Number unique items:
# 18
# The unique items:
# [0.0, 2.0, nan, 1.0, 5.0, 4.0, 3.0, 10.0, 7.0, 8.0, 14.0, 6.0, 20.0, 30.0, 13.0, 21.0, 31.0, 17.0]
# Admitting hospital [EUPATH_0000318]
# Number unique items:
# 7
# The unique items:
# [nan, 'Jinja Hospital', 'Kauka Health Centre', 'Kihihi Health Centre IV', 'Bwindi Hospital', 'Nagongera Health Centre IV', 'Tororo District Hospital']
# Age at visit (years) [EUPATH_0000113]
# Number unique items:
# 5164
# [34.08, 49.4]
# Anorexia [SYMP_0000523]
# Number unique items:
# 4
# The unique items:
# ['No', 'Yes', 'Unable to assess', nan]
# ...

# %%
data.columns
# Out:
# Index(['Observation_Id', 'Participant_Id', 'Household_Id',
#        'Abdominal pain [HP_0002027]',
#        'Abdominal pain duration (days) [EUPATH_0000154]',
#        'Admitting hospital [EUPATH_0000318]',
#        'Age at visit (years) [EUPATH_0000113]', 'Anorexia [SYMP_0000523]',
#        'Anorexia duration (days) [EUPATH_0000155]',
#        'Asexual Plasmodium parasite density, by microscopy [EUPATH_0000092]',
#        'Asexual Plasmodium parasites present, by microscopy [EUPATH_0000048]',
#        'Basis of complicated diagnosis [EUPATH_0000316]',
#        'Complicated malaria [EUPATH_0000040]', 'Cough [SYMP_0000614]',
#        'Cough duration (days) [EUPATH_0000156]',
#        'Days since enrollment [EUPATH_0000191]',
#        'Diagnosis at hospitalization [EUPATH_0000638]',
#        'Diarrhea [DOID_13250]', 'Diarrhea duration (days) [EUPATH_0000157]',
#        'Fatigue [SYMP_0019177]', 'Fatigue duration (days) [EUPATH_0000158]',
#        'Febrile [EUPATH_0000097]',
# ...
